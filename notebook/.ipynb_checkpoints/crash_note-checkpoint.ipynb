# %%
import pyspark as spark
import numpy as np
import pandas as pd
import sklearn
import geopandas as gpd 
from geopandas import GeoDataFrame
from shapely.geometry import Point, Polygon
import matplotlib.pyplot as plt
import seaborn as sns

# %%
crash = pd.read_csv('../data/Traffic_Crashes_-_Crashes.csv')

# %%
crash.shape
# Out:
# (517282, 49)

# %%
crash.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 517282 entries, 0 to 517281
# Data columns (total 49 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   CRASH_RECORD_ID                517282 non-null  object
#  1   RD_NO                          512571 non-null  object
#  2   CRASH_DATE_EST_I               39076 non-null   object
#  3   CRASH_DATE                     517282 non-null  object
#  4   POSTED_SPEED_LIMIT             517282 non-null  int64
#  5   TRAFFIC_CONTROL_DEVICE         517282 non-null  object
#  6   DEVICE_CONDITION               517282 non-null  object
#  7   WEATHER_CONDITION              517282 non-null  object
#  8   LIGHTING_CONDITION             517282 non-null  object
#  9   FIRST_CRASH_TYPE               517282 non-null  object
#  10  TRAFFICWAY_TYPE                517282 non-null  object
#  11  LANE_CNT                       198966 non-null  float64
#  12  ALIGNMENT                      517282 non-null  object
#  13  ROADWAY_SURFACE_COND           517282 non-null  object
#  14  ROAD_DEFECT                    517282 non-null  object
#  15  REPORT_TYPE                    504512 non-null  object
#  16  CRASH_TYPE                     517282 non-null  object
#  17  INTERSECTION_RELATED_I         117084 non-null  object
#  18  NOT_RIGHT_OF_WAY_I             24517 non-null   object
#  19  HIT_AND_RUN_I                  154465 non-null  object
#  20  DAMAGE                         517282 non-null  object
#  21  DATE_POLICE_NOTIFIED           517282 non-null  object
#  22  PRIM_CONTRIBUTORY_CAUSE        517282 non-null  object
#  23  SEC_CONTRIBUTORY_CAUSE         517282 non-null  object
#  24  STREET_NO                      517282 non-null  int64
#  25  STREET_DIRECTION               517279 non-null  object
#  26  STREET_NAME                    517281 non-null  object
#  27  BEAT_OF_OCCURRENCE             517277 non-null  float64
#  28  PHOTOS_TAKEN_I                 6462 non-null    object
#  29  STATEMENTS_TAKEN_I             10492 non-null   object
#  30  DOORING_I                      1650 non-null    object
#  31  WORK_ZONE_I                    3278 non-null    object
#  32  WORK_ZONE_TYPE                 2590 non-null    object
#  33  WORKERS_PRESENT_I              803 non-null     object
#  34  NUM_UNITS                      517282 non-null  int64
#  35  MOST_SEVERE_INJURY             516233 non-null  object
#  36  INJURIES_TOTAL                 516244 non-null  float64
#  37  INJURIES_FATAL                 516244 non-null  float64
#  38  INJURIES_INCAPACITATING        516244 non-null  float64
#  39  INJURIES_NON_INCAPACITATING    516244 non-null  float64
#  40  INJURIES_REPORTED_NOT_EVIDENT  516244 non-null  float64
#  41  INJURIES_NO_INDICATION         516244 non-null  float64
#  42  INJURIES_UNKNOWN               516244 non-null  float64
#  43  CRASH_HOUR                     517282 non-null  int64
#  44  CRASH_DAY_OF_WEEK              517282 non-null  int64
#  45  CRASH_MONTH                    517282 non-null  int64
#  46  LATITUDE                       514382 non-null  float64
#  47  LONGITUDE                      514382 non-null  float64
#  48  LOCATION                       514382 non-null  object
# dtypes: float64(11), int64(6), object(32)
# memory usage: 193.4+ MB

# %%
crash['TRAFFICWAY_TYPE'].value_counts()
# Out:
# NOT DIVIDED                        229700
# DIVIDED - W/MEDIAN (NOT RAISED)     90468
# ONE-WAY                             68639
# PARKING LOT                         36546
# DIVIDED - W/MEDIAN BARRIER          30657
# FOUR WAY                            18287
# OTHER                               14623
# ALLEY                                8500
# UNKNOWN                              5601
# CENTER TURN LANE                     4325
# T-INTERSECTION                       3866
# DRIVEWAY                             1791
# RAMP                                 1619
# UNKNOWN INTERSECTION TYPE            1086
# FIVE POINT, OR MORE                   458
# Y-INTERSECTION                        450
# TRAFFIC ROUTE                         336
# NOT REPORTED                          142
# ROUNDABOUT                            120
# L-INTERSECTION                         68
# Name: TRAFFICWAY_TYPE, dtype: int64

# %%
crash['MOST_SEVERE_INJURY'].value_counts()
# Out:
# NO INDICATION OF INJURY     449039
# NONINCAPACITATING INJURY     37381
# REPORTED, NOT EVIDENT        20779
# INCAPACITATING INJURY         8528
# FATAL                          506
# Name: MOST_SEVERE_INJURY, dtype: int64

# %%
crash['NUM_UNITS'].value_counts()
# Out:
# 2     454176
# 1      28012
# 3      27909
# 4       5326
# 5       1250
# 6        373
# 7        135
# 8         51
# 9         27
# 10        10
# 11         5
# 12         3
# 14         2
# 15         1
# 16         1
# 18         1
# Name: NUM_UNITS, dtype: int64

# %%
crash_clean = crash[['CRASH_RECORD_ID','CRASH_DATE','POSTED_SPEED_LIMIT','WEATHER_CONDITION','LIGHTING_CONDITION','FIRST_CRASH_TYPE','ALIGNMENT','ROADWAY_SURFACE_COND','ROAD_DEFECT','CRASH_TYPE','PRIM_CONTRIBUTORY_CAUSE','SEC_CONTRIBUTORY_CAUSE','STREET_DIRECTION','BEAT_OF_OCCURRENCE','WORK_ZONE_I','MOST_SEVERE_INJURY','INJURIES_TOTAL','INJURIES_FATAL','CRASH_HOUR','CRASH_DAY_OF_WEEK','CRASH_MONTH','LATITUDE','LONGITUDE','LOCATION','TRAFFICWAY_TYPE','LANE_CNT']]

# %%
crash_clean
# Out:
#                                           CRASH_RECORD_ID  \
# 0       4fd0a3e0897b3335b94cd8d5b2d2b350eb691add56c62d...
# 1       009e9e67203442370272e1a13d6ee51a4155dac65e583d...
# 2       ee9283eff3a55ac50ee58f3d9528ce1d689b1c4180b4c4...
# 3       f8960f698e870ebdc60b521b2a141a5395556bc3704191...
# 4       8eaa2678d1a127804ee9b8c35ddf7d63d913c14eda61d6...
# ...                                                   ...
# 517277  8177e1b192fa48f2031a46b96f36de00cf134a897106c7...
# 517278  b97a293c86c5720620b2c993ff91e46c90e129283ce883...
# 517279  c071056bc7969311010acb313722c4a2090c5be655b7ed...
# 517280  ce5ecae9555f96005905f51818101855eb30b626d49464...
# 517281  f829a8bd9a1afc120ed6720cdb20a22b1a90b81278002b...
#
#                     CRASH_DATE  POSTED_SPEED_LIMIT WEATHER_CONDITION  \
# 0       07/10/2019 05:56:00 PM                  35             CLEAR
# 1       06/30/2017 04:00:00 PM                  35             CLEAR
# 2       07/10/2020 10:25:00 AM                  30             CLEAR
# 3       07/11/2020 01:00:00 AM                  30             CLEAR
# 4       07/08/2020 02:00:00 PM                  20             CLEAR
# ...                        ...                 ...               ...
# 517277  05/26/2021 03:29:00 PM                  10             CLEAR
# 517278  05/26/2021 08:54:00 PM                  20             CLEAR
# 517279  05/26/2021 04:16:00 AM                  20              RAIN
# 517280  05/26/2021 12:45:00 PM                  30             CLEAR
# 517281  01/06/2020 08:30:00 AM                  15             CLEAR
#
#             LIGHTING_CONDITION      FIRST_CRASH_TYPE           ALIGNMENT  \
# 0                     DAYLIGHT               TURNING  STRAIGHT AND LEVEL
# 1                     DAYLIGHT               TURNING  STRAIGHT AND LEVEL
# 2                     DAYLIGHT              REAR END  STRAIGHT AND LEVEL
# 3                     DARKNESS  PARKED MOTOR VEHICLE  STRAIGHT AND LEVEL
# 4                     DAYLIGHT  PARKED MOTOR VEHICLE  STRAIGHT AND LEVEL
# ...                        ...                   ...                 ...
# 517277                DAYLIGHT              REAR END  STRAIGHT AND LEVEL
# 517278  DARKNESS, LIGHTED ROAD          PEDALCYCLIST  STRAIGHT AND LEVEL
# 517279  DARKNESS, LIGHTED ROAD  PARKED MOTOR VEHICLE  STRAIGHT AND LEVEL
# 517280                DAYLIGHT               TURNING  STRAIGHT AND LEVEL
# 517281                DAYLIGHT                 ANGLE  STRAIGHT AND LEVEL
#
#        ROADWAY_SURFACE_COND ROAD_DEFECT                        CRASH_TYPE  \
# 0                       DRY  NO DEFECTS            NO INJURY / DRIVE AWAY
# 1                       DRY  NO DEFECTS  INJURY AND / OR TOW DUE TO CRASH
# 2                       DRY  NO DEFECTS            NO INJURY / DRIVE AWAY
# 3                       DRY  NO DEFECTS            NO INJURY / DRIVE AWAY
# 4                       DRY  NO DEFECTS            NO INJURY / DRIVE AWAY
# ...                     ...         ...                               ...
# 517277                  DRY  NO DEFECTS            NO INJURY / DRIVE AWAY
# 517278                  DRY  NO DEFECTS            NO INJURY / DRIVE AWAY
# 517279                  WET  NO DEFECTS            NO INJURY / DRIVE AWAY
# 517280                  DRY  NO DEFECTS            NO INJURY / DRIVE AWAY
# 517281                  DRY  NO DEFECTS            NO INJURY / DRIVE AWAY
#
#         ...       MOST_SEVERE_INJURY INJURIES_TOTAL INJURIES_FATAL  \
# 0       ...  NO INDICATION OF INJURY            0.0            0.0
# 1       ...  NO INDICATION OF INJURY            0.0            0.0
# 2       ...  NO INDICATION OF INJURY            0.0            0.0
# 3       ...  NO INDICATION OF INJURY            0.0            0.0
# 4       ...  NO INDICATION OF INJURY            0.0            0.0
# ...     ...                      ...            ...            ...
# 517277  ...  NO INDICATION OF INJURY            0.0            0.0
# 517278  ...  NO INDICATION OF INJURY            0.0            0.0
# 517279  ...  NO INDICATION OF INJURY            0.0            0.0
# 517280  ...  NO INDICATION OF INJURY            0.0            0.0
# 517281  ...  NO INDICATION OF INJURY            0.0            0.0
#
#         CRASH_HOUR CRASH_DAY_OF_WEEK CRASH_MONTH   LATITUDE  LONGITUDE  \
# 0               17                 4           7  41.919664 -87.773288
# 1               16                 6           6  41.741804 -87.740954
# 2               10                 6           7  41.773456 -87.585022
# 3                1                 7           7  41.802119 -87.622115
# 4               14                 4           7        NaN        NaN
# ...            ...               ...         ...        ...        ...
# 517277          15                 4           5  41.696314 -87.596632
# 517278          20                 4           5  41.918463 -87.650799
# 517279           4                 4           5  41.778846 -87.686224
# 517280          12                 4           5  41.784840 -87.664204
# 517281           8                 2           1  41.865595 -87.623964
#
#                                         LOCATION  \
# 0       POINT (-87.773287883007 41.919663832993)
# 1       POINT (-87.740953581987 41.741803598989)
# 2       POINT (-87.585022352022 41.773455972008)
# 3       POINT (-87.622114914961 41.802118543011)
# 4                                            NaN
# ...                                          ...
# 517277  POINT (-87.596632243933 41.696313683973)
# 517278  POINT (-87.650799033359 41.918462595697)
# 517279  POINT (-87.686224330667 41.778846489565)
# 517280  POINT (-87.664204193636 41.784840316339)
# 517281   POINT (-87.62396444716 41.865594951208)
#
#                         TRAFFICWAY_TYPE
# 0                               ONE-WAY
# 1                           NOT DIVIDED
# 2                              FOUR WAY
# 3       DIVIDED - W/MEDIAN (NOT RAISED)
# 4                              DRIVEWAY
# ...                                 ...
# 517277                      PARKING LOT
# 517278                            ALLEY
# 517279                          ONE-WAY
# 517280                   T-INTERSECTION
# 517281                            ALLEY
#
# [517282 rows x 25 columns]

# %%
crash['BEAT_OF_OCCURRENCE'].value_counts()
# Out:
# 1834.0    6679
# 114.0     5426
# 1831.0    5165
# 122.0     5162
# 813.0     4985
#           ...
# 1125.0     492
# 1653.0     196
# 1652.0      82
# 1655.0      75
# 6100.0       1
# Name: BEAT_OF_OCCURRENCE, Length: 275, dtype: int64

# %%
crash_clean.describe()
# Out:
#        POSTED_SPEED_LIMIT  BEAT_OF_OCCURRENCE  INJURIES_TOTAL  INJURIES_FATAL  \
# count       517282.000000       517277.000000    516244.00000   516244.000000
# mean            28.302120         1239.329638         0.17882        0.001060
# std              6.444674          707.065267         0.55063        0.035331
# min              0.000000          111.000000         0.00000        0.000000
# 25%             30.000000          712.000000         0.00000        0.000000
# 50%             30.000000         1211.000000         0.00000        0.000000
# 75%             30.000000         1822.000000         0.00000        0.000000
# max             99.000000         6100.000000        21.00000        4.000000
#
#           CRASH_HOUR  CRASH_DAY_OF_WEEK    CRASH_MONTH       LATITUDE  \
# count  517282.000000      517282.000000  517282.000000  514382.000000
# mean       13.242158           4.126892       6.573674      41.855046
# std         5.506523           1.977442       3.438811       0.336088
# min         0.000000           1.000000       1.000000       0.000000
# 25%         9.000000           2.000000       4.000000      41.782219
# 50%        14.000000           4.000000       7.000000      41.875409
# 75%        17.000000           6.000000      10.000000      41.924046
# max        23.000000           7.000000      12.000000      42.022780
#
#            LONGITUDE
# count  514382.000000
# mean      -87.673046
# std         0.683169
# min       -87.934763
# 25%       -87.721285
# 50%       -87.673455
# 75%       -87.632828
# max         0.000000

# %%
crash_clean.isnull().sum()
# Out:
# CRASH_RECORD_ID                 0
# CRASH_DATE                      0
# POSTED_SPEED_LIMIT              0
# WEATHER_CONDITION               0
# LIGHTING_CONDITION              0
# FIRST_CRASH_TYPE                0
# ALIGNMENT                       0
# ROADWAY_SURFACE_COND            0
# ROAD_DEFECT                     0
# CRASH_TYPE                      0
# PRIM_CONTRIBUTORY_CAUSE         0
# SEC_CONTRIBUTORY_CAUSE          0
# STREET_DIRECTION                3
# BEAT_OF_OCCURRENCE              5
# WORK_ZONE_I                514004
# MOST_SEVERE_INJURY           1049
# INJURIES_TOTAL               1038
# INJURIES_FATAL               1038
# CRASH_HOUR                      0
# CRASH_DAY_OF_WEEK               0
# CRASH_MONTH                     0
# LATITUDE                     2900
# LONGITUDE                    2900
# LOCATION                     2900
# dtype: int64

# %%
chimap= gpd.read_file('../data/Maps/geo_export_501125fe-60a6-4852-a5cf-5ef96eb419a9.shp')

# %%
geometry = [Point(xy) for xy in zip(crash.LONGITUDE,crash.LATITUDE)]

# %%
gdf = gpd.GeoDataFrame(crash,crs={'init':'epsg:4326'},geometry = geometry)
# Out:
# /Users/winsometang/opt/anaconda3/lib/python3.8/site-packages/pyproj/crs/crs.py:68: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))

# %%
fig,axs=plt.subplots(figsize=(10,10))
ax1=chimap.plot(ax=axs)
ax1.set_xlim()
ax1.set_ylim()

gdf.plot(ax=ax1,color = 'red')
# Out:
# <AxesSubplot:>

# %%
crash_clean['WEATHER_CONDITION'].value_counts()
# Out:
# CLEAR                       409531
# RAIN                         45351
# UNKNOWN                      22645
# SNOW                         20310
# CLOUDY/OVERCAST              15388
# OTHER                         1616
# FOG/SMOKE/HAZE                 837
# SLEET/HAIL                     722
# FREEZING RAIN/DRIZZLE          612
# BLOWING SNOW                   166
# SEVERE CROSS WIND GATE         102
# BLOWING SAND, SOIL, DIRT         2
# Name: WEATHER_CONDITION, dtype: int64

# %%
crash_clean['ROAD_DEFECT'].value_counts()
# Out:
# NO DEFECTS           429237
# UNKNOWN               76848
# RUT, HOLES             4620
# OTHER                  2920
# WORN SURFACE           2110
# SHOULDER DEFECT        1108
# DEBRIS ON ROADWAY       439
# Name: ROAD_DEFECT, dtype: int64

# %%
crash_clean['LIGHTING_CONDITION'].value_counts()
# Out:
# DAYLIGHT                  336395
# DARKNESS, LIGHTED ROAD    111367
# DARKNESS                   25869
# UNKNOWN                    19015
# DUSK                       15731
# DAWN                        8905
# Name: LIGHTING_CONDITION, dtype: int64

# %%
crash_clean['ROADWAY_SURFACE_COND'].value_counts()
# Out:
# DRY                386855
# WET                 70089
# UNKNOWN             34538
# SNOW OR SLUSH       20426
# ICE                  3928
# OTHER                1223
# SAND, MUD, DIRT       223
# Name: ROADWAY_SURFACE_COND, dtype: int64

# %%
crash['INJURIES_INCAPACITATING'].value_counts()
# Out:
# 0.0    507636
# 1.0      7547
# 2.0       786
# 3.0       190
# 4.0        66
# 5.0        15
# 6.0         3
# 7.0         1
# Name: INJURIES_INCAPACITATING, dtype: int64

# %%
crash['INJURIES_INCAPACITATING'].value_counts()
# Out:
# 0.0    507636
# 1.0      7547
# 2.0       786
# 3.0       190
# 4.0        66
# 5.0        15
# 6.0         3
# 7.0         1
# Name: INJURIES_INCAPACITATING, dtype: int64

# %%
crash['DAMAGE'].value_counts()
# Out:
# OVER $1,500      302037
# $501 - $1,500    149766
# $500 OR LESS      65479
# Name: DAMAGE, dtype: int64

# %%
crash_clean
# Out:
#                                           CRASH_RECORD_ID  \
# 0       4fd0a3e0897b3335b94cd8d5b2d2b350eb691add56c62d...
# 1       009e9e67203442370272e1a13d6ee51a4155dac65e583d...
# 2       ee9283eff3a55ac50ee58f3d9528ce1d689b1c4180b4c4...
# 3       f8960f698e870ebdc60b521b2a141a5395556bc3704191...
# 4       8eaa2678d1a127804ee9b8c35ddf7d63d913c14eda61d6...
# ...                                                   ...
# 517277  8177e1b192fa48f2031a46b96f36de00cf134a897106c7...
# 517278  b97a293c86c5720620b2c993ff91e46c90e129283ce883...
# 517279  c071056bc7969311010acb313722c4a2090c5be655b7ed...
# 517280  ce5ecae9555f96005905f51818101855eb30b626d49464...
# 517281  f829a8bd9a1afc120ed6720cdb20a22b1a90b81278002b...
#
#                     CRASH_DATE  POSTED_SPEED_LIMIT WEATHER_CONDITION  \
# 0       07/10/2019 05:56:00 PM                  35             CLEAR
# 1       06/30/2017 04:00:00 PM                  35             CLEAR
# 2       07/10/2020 10:25:00 AM                  30             CLEAR
# 3       07/11/2020 01:00:00 AM                  30             CLEAR
# 4       07/08/2020 02:00:00 PM                  20             CLEAR
# ...                        ...                 ...               ...
# 517277  05/26/2021 03:29:00 PM                  10             CLEAR
# 517278  05/26/2021 08:54:00 PM                  20             CLEAR
# 517279  05/26/2021 04:16:00 AM                  20              RAIN
# 517280  05/26/2021 12:45:00 PM                  30             CLEAR
# 517281  01/06/2020 08:30:00 AM                  15             CLEAR
#
#             LIGHTING_CONDITION      FIRST_CRASH_TYPE           ALIGNMENT  \
# 0                     DAYLIGHT               TURNING  STRAIGHT AND LEVEL
# 1                     DAYLIGHT               TURNING  STRAIGHT AND LEVEL
# 2                     DAYLIGHT              REAR END  STRAIGHT AND LEVEL
# 3                     DARKNESS  PARKED MOTOR VEHICLE  STRAIGHT AND LEVEL
# 4                     DAYLIGHT  PARKED MOTOR VEHICLE  STRAIGHT AND LEVEL
# ...                        ...                   ...                 ...
# 517277                DAYLIGHT              REAR END  STRAIGHT AND LEVEL
# 517278  DARKNESS, LIGHTED ROAD          PEDALCYCLIST  STRAIGHT AND LEVEL
# 517279  DARKNESS, LIGHTED ROAD  PARKED MOTOR VEHICLE  STRAIGHT AND LEVEL
# 517280                DAYLIGHT               TURNING  STRAIGHT AND LEVEL
# 517281                DAYLIGHT                 ANGLE  STRAIGHT AND LEVEL
#
#        ROADWAY_SURFACE_COND ROAD_DEFECT                        CRASH_TYPE  \
# 0                       DRY  NO DEFECTS            NO INJURY / DRIVE AWAY
# 1                       DRY  NO DEFECTS  INJURY AND / OR TOW DUE TO CRASH
# 2                       DRY  NO DEFECTS            NO INJURY / DRIVE AWAY
# 3                       DRY  NO DEFECTS            NO INJURY / DRIVE AWAY
# 4                       DRY  NO DEFECTS            NO INJURY / DRIVE AWAY
# ...                     ...         ...                               ...
# 517277                  DRY  NO DEFECTS            NO INJURY / DRIVE AWAY
# 517278                  DRY  NO DEFECTS            NO INJURY / DRIVE AWAY
# 517279                  WET  NO DEFECTS            NO INJURY / DRIVE AWAY
# 517280                  DRY  NO DEFECTS            NO INJURY / DRIVE AWAY
# 517281                  DRY  NO DEFECTS            NO INJURY / DRIVE AWAY
#
#         ... WORK_ZONE_I       MOST_SEVERE_INJURY INJURIES_TOTAL  \
# 0       ...         NaN  NO INDICATION OF INJURY            0.0
# 1       ...         NaN  NO INDICATION OF INJURY            0.0
# 2       ...         NaN  NO INDICATION OF INJURY            0.0
# 3       ...         NaN  NO INDICATION OF INJURY            0.0
# 4       ...         NaN  NO INDICATION OF INJURY            0.0
# ...     ...         ...                      ...            ...
# 517277  ...         NaN  NO INDICATION OF INJURY            0.0
# 517278  ...         NaN  NO INDICATION OF INJURY            0.0
# 517279  ...         NaN  NO INDICATION OF INJURY            0.0
# 517280  ...         NaN  NO INDICATION OF INJURY            0.0
# 517281  ...         NaN  NO INDICATION OF INJURY            0.0
#
#         INJURIES_FATAL CRASH_HOUR CRASH_DAY_OF_WEEK  CRASH_MONTH   LATITUDE  \
# 0                  0.0         17                 4            7  41.919664
# 1                  0.0         16                 6            6  41.741804
# 2                  0.0         10                 6            7  41.773456
# 3                  0.0          1                 7            7  41.802119
# 4                  0.0         14                 4            7        NaN
# ...                ...        ...               ...          ...        ...
# 517277             0.0         15                 4            5  41.696314
# 517278             0.0         20                 4            5  41.918463
# 517279             0.0          4                 4            5  41.778846
# 517280             0.0         12                 4            5  41.784840
# 517281             0.0          8                 2            1  41.865595
#
#         LONGITUDE                                  LOCATION
# 0      -87.773288  POINT (-87.773287883007 41.919663832993)
# 1      -87.740954  POINT (-87.740953581987 41.741803598989)
# 2      -87.585022  POINT (-87.585022352022 41.773455972008)
# 3      -87.622115  POINT (-87.622114914961 41.802118543011)
# 4             NaN                                       NaN
# ...           ...                                       ...
# 517277 -87.596632  POINT (-87.596632243933 41.696313683973)
# 517278 -87.650799  POINT (-87.650799033359 41.918462595697)
# 517279 -87.686224  POINT (-87.686224330667 41.778846489565)
# 517280 -87.664204  POINT (-87.664204193636 41.784840316339)
# 517281 -87.623964   POINT (-87.62396444716 41.865594951208)
#
# [517282 rows x 24 columns]

# %%
crash_clean["INJURIES_TOTAL"].value_counts()
# Out:
# 0.0     449050
# 1.0      50774
# 2.0      11096
# 3.0       3356
# 4.0       1209
# 5.0        451
# 6.0        177
# 7.0         66
# 8.0         23
# 9.0         15
# 10.0         9
# 15.0         5
# 11.0         5
# 21.0         2
# 13.0         2
# 12.0         2
# 19.0         1
# 16.0         1
# Name: INJURIES_TOTAL, dtype: int64

# %%
crash_clean["INJURIES_FATAL"].value_counts()
# Out:
# 0.0    515738
# 1.0       472
# 2.0        28
# 3.0         5
# 4.0         1
# Name: INJURIES_FATAL, dtype: int64

# %%
crash_clean.isnull().sum()
# Out:
# CRASH_RECORD_ID                 0
# CRASH_DATE                      0
# POSTED_SPEED_LIMIT              0
# WEATHER_CONDITION               0
# LIGHTING_CONDITION              0
# FIRST_CRASH_TYPE                0
# ALIGNMENT                       0
# ROADWAY_SURFACE_COND            0
# ROAD_DEFECT                     0
# CRASH_TYPE                      0
# PRIM_CONTRIBUTORY_CAUSE         0
# SEC_CONTRIBUTORY_CAUSE          0
# STREET_DIRECTION                3
# BEAT_OF_OCCURRENCE              5
# WORK_ZONE_I                514004
# MOST_SEVERE_INJURY           1049
# INJURIES_TOTAL               1038
# INJURIES_FATAL               1038
# CRASH_HOUR                      0
# CRASH_DAY_OF_WEEK               0
# CRASH_MONTH                     0
# LATITUDE                     2900
# LONGITUDE                    2900
# LOCATION                     2900
# dtype: int64

# %%
crash_clean['WORK_ZONE_I'] = crash_clean['WORK_ZONE_I'].fillna("N")
# Out:
# /var/folders/nt/rg8_jkq90v77r8l8dc_9wl0m0000gn/T/ipykernel_6531/3014417222.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   crash_clean['WORK_ZONE_I'] = crash_clean['WORK_ZONE_I'].fillna("N")

# %%
crash_clean['INJURIES_TOTAL'] = crash_clean['INJURIES_TOTAL'].fillna("UNKNOWN")
# Out:
# /var/folders/nt/rg8_jkq90v77r8l8dc_9wl0m0000gn/T/ipykernel_6531/3936452071.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   crash_clean['INJURIES_TOTAL'] = crash_clean['INJURIES_TOTAL'].fillna("UNKNOWN")

# %%
crash_clean['INJURIES_FATAL'] = crash_clean['INJURIES_FATAL'].fillna("UNKNOWN")
# Out:
# /var/folders/nt/rg8_jkq90v77r8l8dc_9wl0m0000gn/T/ipykernel_6531/446342431.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   crash_clean['INJURIES_FATAL'] = crash_clean['INJURIES_FATAL'].fillna("UNKNOWN")

# %%
crash_clean['MOST_SEVERE_INJURY'] = crash_clean['MOST_SEVERE_INJURY'].fillna("UNKNOWN")
# Out:
# /var/folders/nt/rg8_jkq90v77r8l8dc_9wl0m0000gn/T/ipykernel_6531/1774345082.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   crash_clean['MOST_SEVERE_INJURY'] = crash_clean['MOST_SEVERE_INJURY'].fillna("UNKNOWN")

# %%
crash_clean['BEAT_OF_OCCURRENCE'] = crash_clean['BEAT_OF_OCCURRENCE'].fillna("UNKNOWN")
# Out:
# /var/folders/nt/rg8_jkq90v77r8l8dc_9wl0m0000gn/T/ipykernel_6531/2011030385.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   crash_clean['BEAT_OF_OCCURRENCE'] = crash_clean['BEAT_OF_OCCURRENCE'].fillna("UNKNOWN")

# %%
crash_clean["LANE_CNT"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3080             try:
# -> 3081                 return self._engine.get_loc(casted_key)
#    3082             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'LANE_CNT'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/nt/rg8_jkq90v77r8l8dc_9wl0m0000gn/T/ipykernel_6531/1064043396.py in <module>
# ----> 1 crash_clean["LANE_CNT"].value_counts()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3081                 return self._engine.get_loc(casted_key)
#    3082             except KeyError as err:
# -> 3083                 raise KeyError(key) from err
#    3084
#    3085         if tolerance is not None:
#
# KeyError: 'LANE_CNT'

# %%
corr = crash_clean.corr()
mask = np.triu(np.ones_like(corr,dtype = np.bool))
sns.set_style(style = 'white')
f,ax = plt.subplots(figsize=(10,10))
cmap = sns.diverging_palette(10,250,as_cmap = True)
sns.heatmap(corr,mask=mask,cmap=cmap,
           square = True
           )
# Out:
# /var/folders/nt/rg8_jkq90v77r8l8dc_9wl0m0000gn/T/ipykernel_6531/803585571.py:2: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = np.triu(np.ones_like(corr,dtype = np.bool))
# <AxesSubplot:>

# %%
crash_clean
# Out:
#                                           CRASH_RECORD_ID  \
# 0       4fd0a3e0897b3335b94cd8d5b2d2b350eb691add56c62d...
# 1       009e9e67203442370272e1a13d6ee51a4155dac65e583d...
# 2       ee9283eff3a55ac50ee58f3d9528ce1d689b1c4180b4c4...
# 3       f8960f698e870ebdc60b521b2a141a5395556bc3704191...
# 4       8eaa2678d1a127804ee9b8c35ddf7d63d913c14eda61d6...
# ...                                                   ...
# 517277  8177e1b192fa48f2031a46b96f36de00cf134a897106c7...
# 517278  b97a293c86c5720620b2c993ff91e46c90e129283ce883...
# 517279  c071056bc7969311010acb313722c4a2090c5be655b7ed...
# 517280  ce5ecae9555f96005905f51818101855eb30b626d49464...
# 517281  f829a8bd9a1afc120ed6720cdb20a22b1a90b81278002b...
#
#                     CRASH_DATE  POSTED_SPEED_LIMIT WEATHER_CONDITION  \
# 0       07/10/2019 05:56:00 PM                  35             CLEAR
# 1       06/30/2017 04:00:00 PM                  35             CLEAR
# 2       07/10/2020 10:25:00 AM                  30             CLEAR
# 3       07/11/2020 01:00:00 AM                  30             CLEAR
# 4       07/08/2020 02:00:00 PM                  20             CLEAR
# ...                        ...                 ...               ...
# 517277  05/26/2021 03:29:00 PM                  10             CLEAR
# 517278  05/26/2021 08:54:00 PM                  20             CLEAR
# 517279  05/26/2021 04:16:00 AM                  20              RAIN
# 517280  05/26/2021 12:45:00 PM                  30             CLEAR
# 517281  01/06/2020 08:30:00 AM                  15             CLEAR
#
#             LIGHTING_CONDITION      FIRST_CRASH_TYPE           ALIGNMENT  \
# 0                     DAYLIGHT               TURNING  STRAIGHT AND LEVEL
# 1                     DAYLIGHT               TURNING  STRAIGHT AND LEVEL
# 2                     DAYLIGHT              REAR END  STRAIGHT AND LEVEL
# 3                     DARKNESS  PARKED MOTOR VEHICLE  STRAIGHT AND LEVEL
# 4                     DAYLIGHT  PARKED MOTOR VEHICLE  STRAIGHT AND LEVEL
# ...                        ...                   ...                 ...
# 517277                DAYLIGHT              REAR END  STRAIGHT AND LEVEL
# 517278  DARKNESS, LIGHTED ROAD          PEDALCYCLIST  STRAIGHT AND LEVEL
# 517279  DARKNESS, LIGHTED ROAD  PARKED MOTOR VEHICLE  STRAIGHT AND LEVEL
# 517280                DAYLIGHT               TURNING  STRAIGHT AND LEVEL
# 517281                DAYLIGHT                 ANGLE  STRAIGHT AND LEVEL
#
#        ROADWAY_SURFACE_COND ROAD_DEFECT                        CRASH_TYPE  \
# 0                       DRY  NO DEFECTS            NO INJURY / DRIVE AWAY
# 1                       DRY  NO DEFECTS  INJURY AND / OR TOW DUE TO CRASH
# 2                       DRY  NO DEFECTS            NO INJURY / DRIVE AWAY
# 3                       DRY  NO DEFECTS            NO INJURY / DRIVE AWAY
# 4                       DRY  NO DEFECTS            NO INJURY / DRIVE AWAY
# ...                     ...         ...                               ...
# 517277                  DRY  NO DEFECTS            NO INJURY / DRIVE AWAY
# 517278                  DRY  NO DEFECTS            NO INJURY / DRIVE AWAY
# 517279                  WET  NO DEFECTS            NO INJURY / DRIVE AWAY
# 517280                  DRY  NO DEFECTS            NO INJURY / DRIVE AWAY
# 517281                  DRY  NO DEFECTS            NO INJURY / DRIVE AWAY
#
#         ...       MOST_SEVERE_INJURY INJURIES_TOTAL INJURIES_FATAL  \
# 0       ...  NO INDICATION OF INJURY            0.0            0.0
# 1       ...  NO INDICATION OF INJURY            0.0            0.0
# 2       ...  NO INDICATION OF INJURY            0.0            0.0
# 3       ...  NO INDICATION OF INJURY            0.0            0.0
# 4       ...  NO INDICATION OF INJURY            0.0            0.0
# ...     ...                      ...            ...            ...
# 517277  ...  NO INDICATION OF INJURY            0.0            0.0
# 517278  ...  NO INDICATION OF INJURY            0.0            0.0
# 517279  ...  NO INDICATION OF INJURY            0.0            0.0
# 517280  ...  NO INDICATION OF INJURY            0.0            0.0
# 517281  ...  NO INDICATION OF INJURY            0.0            0.0
#
#         CRASH_HOUR CRASH_DAY_OF_WEEK CRASH_MONTH   LATITUDE  LONGITUDE  \
# 0               17                 4           7  41.919664 -87.773288
# 1               16                 6           6  41.741804 -87.740954
# 2               10                 6           7  41.773456 -87.585022
# 3                1                 7           7  41.802119 -87.622115
# 4               14                 4           7        NaN        NaN
# ...            ...               ...         ...        ...        ...
# 517277          15                 4           5  41.696314 -87.596632
# 517278          20                 4           5  41.918463 -87.650799
# 517279           4                 4           5  41.778846 -87.686224
# 517280          12                 4           5  41.784840 -87.664204
# 517281           8                 2           1  41.865595 -87.623964
#
#                                         LOCATION  \
# 0       POINT (-87.773287883007 41.919663832993)
# 1       POINT (-87.740953581987 41.741803598989)
# 2       POINT (-87.585022352022 41.773455972008)
# 3       POINT (-87.622114914961 41.802118543011)
# 4                                            NaN
# ...                                          ...
# 517277  POINT (-87.596632243933 41.696313683973)
# 517278  POINT (-87.650799033359 41.918462595697)
# 517279  POINT (-87.686224330667 41.778846489565)
# 517280  POINT (-87.664204193636 41.784840316339)
# 517281   POINT (-87.62396444716 41.865594951208)
#
#                         TRAFFICWAY_TYPE
# 0                               ONE-WAY
# 1                           NOT DIVIDED
# 2                              FOUR WAY
# 3       DIVIDED - W/MEDIAN (NOT RAISED)
# 4                              DRIVEWAY
# ...                                 ...
# 517277                      PARKING LOT
# 517278                            ALLEY
# 517279                          ONE-WAY
# 517280                   T-INTERSECTION
# 517281                            ALLEY
#
# [517282 rows x 25 columns]

# %%
crash_clean.isnull().sum()
# Out:
# CRASH_RECORD_ID               0
# CRASH_DATE                    0
# POSTED_SPEED_LIMIT            0
# WEATHER_CONDITION             0
# LIGHTING_CONDITION            0
# FIRST_CRASH_TYPE              0
# ALIGNMENT                     0
# ROADWAY_SURFACE_COND          0
# ROAD_DEFECT                   0
# CRASH_TYPE                    0
# PRIM_CONTRIBUTORY_CAUSE       0
# SEC_CONTRIBUTORY_CAUSE        0
# STREET_DIRECTION              3
# BEAT_OF_OCCURRENCE            0
# WORK_ZONE_I                   0
# MOST_SEVERE_INJURY            0
# INJURIES_TOTAL                0
# INJURIES_FATAL                0
# CRASH_HOUR                    0
# CRASH_DAY_OF_WEEK             0
# CRASH_MONTH                   0
# LATITUDE                   2900
# LONGITUDE                  2900
# LOCATION                   2900
# dtype: int64

# %%
crash_clean.columns
# Out:
# Index(['CRASH_RECORD_ID', 'CRASH_DATE', 'POSTED_SPEED_LIMIT',
#        'WEATHER_CONDITION', 'LIGHTING_CONDITION', 'FIRST_CRASH_TYPE',
#        'ALIGNMENT', 'ROADWAY_SURFACE_COND', 'ROAD_DEFECT', 'CRASH_TYPE',
#        'PRIM_CONTRIBUTORY_CAUSE', 'SEC_CONTRIBUTORY_CAUSE', 'STREET_DIRECTION',
#        'BEAT_OF_OCCURRENCE', 'WORK_ZONE_I', 'MOST_SEVERE_INJURY',
#        'INJURIES_TOTAL', 'INJURIES_FATAL', 'CRASH_HOUR', 'CRASH_DAY_OF_WEEK',
#        'CRASH_MONTH', 'LATITUDE', 'LONGITUDE', 'LOCATION', 'TRAFFICWAY_TYPE',
#        'LANE_CNT'],
#       dtype='object')

# %%
dum_clean_crash= pd.get_dummies(crash_clean,columns = ['POSTED_SPEED_LIMIT',
       'WEATHER_CONDITION', 'LIGHTING_CONDITION', 'FIRST_CRASH_TYPE',
       'ALIGNMENT', 'ROADWAY_SURFACE_COND', 'ROAD_DEFECT', 'CRASH_TYPE',
       'PRIM_CONTRIBUTORY_CAUSE', 'SEC_CONTRIBUTORY_CAUSE', 'STREET_DIRECTION',
       'BEAT_OF_OCCURRENCE', 'WORK_ZONE_I', 'MOST_SEVERE_INJURY',
       'INJURIES_TOTAL', 'INJURIES_FATAL', 'CRASH_HOUR', 'CRASH_DAY_OF_WEEK',
       'CRASH_MONTH','TRAFFICWAY_TYPE',
       'LANE_CNT'],drop_first = True )

# %%
dum_clean_crash

# %%
corr = dum_clean_crash.corr()
mask = np.triu(np.ones_like(corr,dtype = np.bool))
sns.set_style(style = 'white')
f,ax = plt.subplots(figsize=(10,10))
cmap = sns.diverging_palette(10,250,as_cmap = True)
sns.heatmap(corr,mask=mask,cmap=cmap,
           square = True
           )
